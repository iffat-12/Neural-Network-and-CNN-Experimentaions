# %% [markdown]
# ## **Import Libraries**

# %%
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.utils import to_categorical

# %% [markdown]
# ## **Load Dataset**

# %%
# load cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# ## **PreProcess / Normalize Dataset**

# %%
#function to pre-process data

def preprocess_data(x, y):
    x = x.astype('float32')
    x /= 255.0

    y = tf.keras.utils.to_categorical(y, 10)

    return x, y

# %% [markdown]
# # **Regular Neural Network**

# %%
# define regular neural network

def regular_nn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# \

# %%
# Preprocessing

x_train, y_train = preprocess_data(x_train, y_train)
x_test, y_test = preprocess_data(x_test, y_test)

# %% [markdown]
# ## **Train Regular Neural Network Model**

# %%
# Training

reg_model = regular_nn(0.01)

history_nn = reg_model.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 8s 5ms/step - loss: 2.1920 - accuracy: 0.1835 - val_loss: 2.0147 - val_accuracy: 0.2961
# Epoch 2/50
# 625/625 [==============================] - 2s 4ms/step - loss: 2.0490 - accuracy: 0.2453 - val_loss: 1.9132 - val_accuracy: 0.3399
# Epoch 3/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.9752 - accuracy: 0.2789 - val_loss: 1.8738 - val_accuracy: 0.3467
# Epoch 4/50
# 625/625 [==============================] - 2s 4ms/step - loss: 1.9335 - accuracy: 0.2943 - val_loss: 1.8225 - val_accuracy: 0.3615
# Epoch 5/50
# 625/625 [==============================] - 2s 4ms/step - loss: 1.9027 - accuracy: 0.3099 - val_loss: 1.7937 - val_accuracy: 0.3733
# Epoch 6/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.8785 - accuracy: 0.3225 - val_loss: 1.7698 - val_accuracy: 0.3897
# Epoch 7/50
# ...

# %%
# Training NN with different hyperparameters

reg_model_1 = regular_nn(0.02)

history_nn_1 = reg_model_1.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 4s 5ms/step - loss: 2.1512 - accuracy: 0.2001 - val_loss: 1.9773 - val_accuracy: 0.3044
# Epoch 2/50
# 625/625 [==============================] - 3s 4ms/step - loss: 2.0013 - accuracy: 0.2658 - val_loss: 1.9117 - val_accuracy: 0.3165
# Epoch 3/50
# 625/625 [==============================] - 2s 4ms/step - loss: 1.9476 - accuracy: 0.2914 - val_loss: 1.8544 - val_accuracy: 0.3413
# Epoch 4/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.9036 - accuracy: 0.3122 - val_loss: 1.8042 - val_accuracy: 0.3560
# Epoch 5/50
# 625/625 [==============================] - 2s 4ms/step - loss: 1.8688 - accuracy: 0.3250 - val_loss: 1.7810 - val_accuracy: 0.3759
# Epoch 6/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.8458 - accuracy: 0.3343 - val_loss: 1.7493 - val_accuracy: 0.3908
# Epoch 7/50
# ...

# %%
# Training NN with different hyperparameters

reg_model_2 = regular_nn(0.03)

history_nn_2 = reg_model_2.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 3s 4ms/step - loss: 2.1652 - accuracy: 0.1865 - val_loss: 2.0134 - val_accuracy: 0.2798
# Epoch 2/50
# 625/625 [==============================] - 3s 4ms/step - loss: 2.0159 - accuracy: 0.2574 - val_loss: 1.9022 - val_accuracy: 0.3234
# Epoch 3/50
# 625/625 [==============================] - 2s 4ms/step - loss: 1.9473 - accuracy: 0.2903 - val_loss: 1.8641 - val_accuracy: 0.3371
# Epoch 4/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.9066 - accuracy: 0.3120 - val_loss: 1.8144 - val_accuracy: 0.3615
# Epoch 5/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.8757 - accuracy: 0.3234 - val_loss: 1.7779 - val_accuracy: 0.3787
# Epoch 6/50
# 625/625 [==============================] - 3s 4ms/step - loss: 1.8506 - accuracy: 0.3299 - val_loss: 1.7624 - val_accuracy: 0.3804
# Epoch 7/50
# ...

# %%
# changing optimizer

def regular_nn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Training NN with different hyperparameters

reg_model_3 = regular_nn(0.03)

history_nn_3 = reg_model_3.fit(x_train, y_train,
                        epochs=50,
                        batch_size=32,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 6s 4ms/step - loss: 2.7608 - accuracy: 0.0993 - val_loss: 2.3069 - val_accuracy: 0.0977
# Epoch 2/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.3066 - accuracy: 0.0993 - val_loss: 2.3070 - val_accuracy: 0.1014
# Epoch 3/50
# 1250/1250 [==============================] - 4s 4ms/step - loss: 2.3066 - accuracy: 0.1001 - val_loss: 2.3096 - val_accuracy: 0.1022
# Epoch 4/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 2.3067 - accuracy: 0.1008 - val_loss: 2.3107 - val_accuracy: 0.1022
# Epoch 5/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.3260 - accuracy: 0.0989 - val_loss: 2.3059 - val_accuracy: 0.1015
# Epoch 6/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 2.3066 - accuracy: 0.1017 - val_loss: 2.3069 - val_accuracy: 0.1022
# Epoch 7/50
# ...

# %%
# Adding layers

def regular_nn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Training NN with different hyperparameters

reg_model_4 = regular_nn(0.03)

history_nn_4 = reg_model_4.fit(x_train, y_train,
                        epochs=50,
                        batch_size=32,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 8s 5ms/step - loss: 2.7018 - accuracy: 0.0997 - val_loss: 2.3053 - val_accuracy: 0.0977
# Epoch 2/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.4739 - accuracy: 0.1011 - val_loss: 2.3049 - val_accuracy: 0.1014
# Epoch 3/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.4310 - accuracy: 0.1005 - val_loss: 2.3110 - val_accuracy: 0.1025
# Epoch 4/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.3067 - accuracy: 0.0984 - val_loss: 2.3045 - val_accuracy: 0.1003
# Epoch 5/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 2.3065 - accuracy: 0.1011 - val_loss: 2.3057 - val_accuracy: 0.1014
# Epoch 6/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 2.3065 - accuracy: 0.0988 - val_loss: 2.3051 - val_accuracy: 0.1003
# Epoch 7/50
# ...

# %% [markdown]
# ## **Evaluate Models**

# %%
# Evaluate

test_loss_reg, test_acc_reg = reg_model.evaluate(x_test, y_test, verbose=1)
test_loss_reg1, test_acc_reg1 = reg_model_1.evaluate(x_test, y_test, verbose=1)
test_loss_reg2, test_acc_reg2 = reg_model_2.evaluate(x_test, y_test, verbose=1)
test_loss_reg3, test_acc_reg3 = reg_model_3.evaluate(x_test, y_test, verbose=1)
test_loss_reg4, test_acc_reg4 = reg_model_4.evaluate(x_test, y_test, verbose=1)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3052 - accuracy: 0.1000

# %% [markdown]
# # **CNN**

# %%
# Define CNN

def cnn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# ## **Training Convolutional Neural Network Models**

# %%
# Train CNN

cnn_model = cnn(0.01)

history_cnn = cnn_model.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 10s 7ms/step - loss: 2.1676 - accuracy: 0.1970 - val_loss: 1.9825 - val_accuracy: 0.2876
# Epoch 2/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.9564 - accuracy: 0.2905 - val_loss: 1.8333 - val_accuracy: 0.3517
# Epoch 3/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.8089 - accuracy: 0.3489 - val_loss: 1.7572 - val_accuracy: 0.3729
# Epoch 4/50
# 625/625 [==============================] - 4s 6ms/step - loss: 1.6804 - accuracy: 0.3943 - val_loss: 1.5658 - val_accuracy: 0.4459
# Epoch 5/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5808 - accuracy: 0.4268 - val_loss: 1.4745 - val_accuracy: 0.4695
# Epoch 6/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5125 - accuracy: 0.4520 - val_loss: 1.4459 - val_accuracy: 0.4857
# Epoch 7/50
# ...

# %%
# Train CNN after chaniging hyperparameters

cnn_model_1 = cnn(0.02)

history_cnn_1 = cnn_model_1.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 5s 6ms/step - loss: 2.1104 - accuracy: 0.2227 - val_loss: 1.9112 - val_accuracy: 0.3297
# Epoch 2/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.8546 - accuracy: 0.3328 - val_loss: 1.7586 - val_accuracy: 0.3765
# Epoch 3/50
# 625/625 [==============================] - 4s 6ms/step - loss: 1.6492 - accuracy: 0.4054 - val_loss: 1.4966 - val_accuracy: 0.4691
# Epoch 4/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.5142 - accuracy: 0.4536 - val_loss: 1.4029 - val_accuracy: 0.4970
# Epoch 5/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.4188 - accuracy: 0.4910 - val_loss: 1.3067 - val_accuracy: 0.5364
# Epoch 6/50
# 625/625 [==============================] - 3s 5ms/step - loss: 1.3481 - accuracy: 0.5190 - val_loss: 1.2515 - val_accuracy: 0.5553
# Epoch 7/50
# ...

# %%
# Define CNN (Increasing Layers)

def cnn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Train CNN after chaniging hyperparameters

cnn_model_2 = cnn(0.03)

history_cnn_2 = cnn_model_2.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 7s 9ms/step - loss: 2.1651 - accuracy: 0.1915 - val_loss: 1.9579 - val_accuracy: 0.2877
# Epoch 2/50
# 625/625 [==============================] - 4s 7ms/step - loss: 1.8437 - accuracy: 0.3301 - val_loss: 1.6500 - val_accuracy: 0.3918
# Epoch 3/50
# 625/625 [==============================] - 5s 8ms/step - loss: 1.6244 - accuracy: 0.4069 - val_loss: 1.5220 - val_accuracy: 0.4494
# Epoch 4/50
# 625/625 [==============================] - 4s 7ms/step - loss: 1.4701 - accuracy: 0.4611 - val_loss: 1.4141 - val_accuracy: 0.4826
# Epoch 5/50
# 625/625 [==============================] - 5s 7ms/step - loss: 1.3608 - accuracy: 0.5043 - val_loss: 1.3226 - val_accuracy: 0.5198
# Epoch 6/50
# 625/625 [==============================] - 5s 8ms/step - loss: 1.2578 - accuracy: 0.5476 - val_loss: 1.2014 - val_accuracy: 0.5692
# Epoch 7/50
# ...

# %%
# Define CNN (Increasing Layers and changing optimizer)

def cnn(lr):
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Train CNN after chaniging hyperparameters

cnn_model_4 = cnn(0.03)

history_cnn_4 = cnn_model_4.fit(x_train, y_train,
                        epochs=50,
                        batch_size=64,
                        validation_split=0.2,
                        verbose=1)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 9s 9ms/step - loss: 47.4670 - accuracy: 0.0997 - val_loss: 2.3037 - val_accuracy: 0.1016
# Epoch 2/50
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3055 - accuracy: 0.1019 - val_loss: 2.3046 - val_accuracy: 0.1022
# Epoch 3/50
# 625/625 [==============================] - 5s 7ms/step - loss: 2.3051 - accuracy: 0.0994 - val_loss: 2.3045 - val_accuracy: 0.0952
# Epoch 4/50
# 625/625 [==============================] - 5s 8ms/step - loss: 2.3052 - accuracy: 0.0998 - val_loss: 2.3039 - val_accuracy: 0.1003
# Epoch 5/50
# 625/625 [==============================] - 5s 7ms/step - loss: 2.3052 - accuracy: 0.0997 - val_loss: 2.3040 - val_accuracy: 0.1016
# Epoch 6/50
# 625/625 [==============================] - 5s 7ms/step - loss: 2.3054 - accuracy: 0.0996 - val_loss: 2.3074 - val_accuracy: 0.0952
# Epoch 7/50
# ...

# %% [markdown]
# ## **Evaluate Model Performance on Test Set**

# %%
# Evaluate CNN

test_loss_cnn, test_acc_cnn = cnn_model.evaluate(x_test, y_test, verbose=2)
test_loss_cnn1, test_acc_cnn1 = cnn_model_1.evaluate(x_test, y_test, verbose=2)
test_loss_cnn2, test_acc_cnn2 = cnn_model_2.evaluate(x_test, y_test, verbose=2)
test_loss_cnn4, test_acc_cnn4 = cnn_model_4.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.8040 - accuracy: 0.7301 - 831ms/epoch - 3ms/step
# 313/313 - 1s - loss: 0.9487 - accuracy: 0.7433 - 1s/epoch - 3ms/step
# 313/313 - 1s - loss: 2.0804 - accuracy: 0.7327 - 1s/epoch - 3ms/step
# 313/313 - 1s - loss: 2.3051 - accuracy: 0.1000 - 964ms/epoch - 3ms/step

# %% [markdown]
# # **Plot Results**

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):

      fig, axs = plt.subplots(1, 2, figsize=(10, 4))

      # Plot the first graph in the left subplot
      axs[0].plot(history.history['accuracy'], label="Train_Acc")
      axs[0].plot(history.history['val_accuracy'], label="Val_Acc")
      axs[0].set_xlabel('Epochs')
      axs[0].set_ylabel('Accuracy')
      axs[0].set_title(title)
      axs[0].legend()

      # Plot the second graph in the right subplot
      axs[1].plot(history.history['loss'], label="Train_Loss")
      axs[1].plot(history.history['val_loss'], label="Val_Loss")
      axs[1].set_xlabel('Epochs')
      axs[1].set_ylabel('Loss')
      axs[1].set_title(title)
      axs[1].legend()

      # Adjust layout and display plot
      plt.tight_layout()
      plt.show()

# %%
# plot accuracy and loss
plot_history(history_nn, 'Regular Neural Network LR: 0.01 Optimizer:SGD')
plot_history(history_cnn, 'Convolutional Neural Network LR: 0.01 Optimizer:SGD')

# %%
# plot accuracy and loss
plot_history(history_nn_1, 'Regular Neural Network LR: 0.02 Optimizer:SGD')
plot_history(history_cnn_1, 'Convolutional Neural Network LR: 0.02 Optimizer:SGD')

# %%
# plot accuracy and loss
plot_history(history_nn_2, 'Regular Neural Network LR: 0.03 Optimizer:SGD')
plot_history(history_cnn_2, 'Convolutional Neural Network LR: 0.03 Optimizer:SGD')

# %%
# plot accuracy and loss
plot_history(history_nn_3, 'Regular Neural Network LR: 0.03 Optimizer:Adam')

# %%
# plot accuracy and loss
plot_history(history_nn_4, 'Regular Neural Network LR: 0.03 Optimizer:Adam')
plot_history(history_cnn_4, 'Convolutional Neural Network LR: 0.03 Optimizer:Adam')

# %% [markdown]
# # **Classification Report**

# %%
from sklearn.metrics import classification_report
import numpy as np

reg_pred = reg_model.predict(x_test, verbose=2)
reg_pred_classes = np.argmax(reg_pred, axis=1)
reg_true_classes = np.argmax(y_test, axis=1)

cnn_pred = cnn_model.predict(x_test, verbose=2)
cnn_pred_classes = np.argmax(cnn_pred, axis=1)
cnn_true_classes = np.argmax(y_test, axis=1)

reg_report = classification_report(reg_true_classes, reg_pred_classes)
cnn_report = classification_report(cnn_true_classes, cnn_pred_classes)

print('Regular NN:\n', reg_report)
print('CNN:\n', cnn_report)
# Out:
# 313/313 - 0s - 463ms/epoch - 1ms/step
# 313/313 - 1s - 531ms/epoch - 2ms/step
# Regular NN:
#                precision    recall  f1-score   support
#
#            0       0.56      0.51      0.53      1000
#            1       0.60      0.62      0.61      1000
#            2       0.34      0.25      0.29      1000
#            3       0.33      0.39      0.35      1000
#            4       0.41      0.45      0.43      1000
#            5       0.45      0.31      0.36      1000
#            6       0.41      0.68      0.51      1000
#            7       0.67      0.46      0.54      1000
#            8       0.55      0.66      0.60      1000
#            9       0.58      0.48      0.53      1000
#
#     accuracy                           0.48     10000
#    macro avg       0.49      0.48      0.48     10000
# weighted avg       0.49      0.48      0.48     10000
#
# CNN:
#                precision    recall  f1-score   support
#
# ...

# %%
from sklearn.metrics import classification_report
import numpy as np

reg_pred = reg_model_1.predict(x_test, verbose=2)
reg_pred_classes = np.argmax(reg_pred, axis=1)
reg_true_classes = np.argmax(y_test, axis=1)

cnn_pred = cnn_model_1.predict(x_test, verbose=2)
cnn_pred_classes = np.argmax(cnn_pred, axis=1)
cnn_true_classes = np.argmax(y_test, axis=1)

reg_report = classification_report(reg_true_classes, reg_pred_classes)
cnn_report = classification_report(cnn_true_classes, cnn_pred_classes)

print('Regular NN:\n', reg_report)
print('CNN:\n', cnn_report)
# Out:
# 313/313 - 1s - 521ms/epoch - 2ms/step
# 313/313 - 1s - 786ms/epoch - 3ms/step
# Regular NN:
#                precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50      1000
#            1       0.68      0.45      0.55      1000
#            2       0.39      0.21      0.27      1000
#            3       0.34      0.25      0.29      1000
#            4       0.44      0.45      0.44      1000
#            5       0.39      0.40      0.40      1000
#            6       0.46      0.66      0.54      1000
#            7       0.52      0.58      0.55      1000
#            8       0.53      0.75      0.62      1000
#            9       0.49      0.62      0.55      1000
#
#     accuracy                           0.48     10000
#    macro avg       0.48      0.48      0.47     10000
# weighted avg       0.48      0.48      0.47     10000
#
# CNN:
#                precision    recall  f1-score   support
#
# ...

# %%
from sklearn.metrics import classification_report
import numpy as np

reg_pred = reg_model_2.predict(x_test, verbose=2)
reg_pred_classes = np.argmax(reg_pred, axis=1)
reg_true_classes = np.argmax(y_test, axis=1)

cnn_pred = cnn_model_2.predict(x_test, verbose=2)
cnn_pred_classes = np.argmax(cnn_pred, axis=1)
cnn_true_classes = np.argmax(y_test, axis=1)

reg_report = classification_report(reg_true_classes, reg_pred_classes)
cnn_report = classification_report(cnn_true_classes, cnn_pred_classes)

print('Regular NN:\n', reg_report)
print('CNN:\n', cnn_report)
# Out:
# 313/313 - 1s - 500ms/epoch - 2ms/step
# 313/313 - 1s - 732ms/epoch - 2ms/step
# Regular NN:
#                precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50      1000
#            1       0.61      0.51      0.56      1000
#            2       0.39      0.24      0.30      1000
#            3       0.33      0.27      0.30      1000
#            4       0.44      0.39      0.41      1000
#            5       0.37      0.38      0.37      1000
#            6       0.47      0.61      0.53      1000
#            7       0.51      0.56      0.54      1000
#            8       0.58      0.66      0.62      1000
#            9       0.43      0.68      0.53      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.47      0.47      0.47     10000
# weighted avg       0.47      0.47      0.47     10000
#
# CNN:
#                precision    recall  f1-score   support
#
# ...

# %%
from sklearn.metrics import classification_report
import numpy as np

reg_pred = reg_model_3.predict(x_test, verbose=2)
reg_pred_classes = np.argmax(reg_pred, axis=1)
reg_true_classes = np.argmax(y_test, axis=1)

reg_report = classification_report(reg_true_classes, reg_pred_classes)

print('Regular NN:\n', reg_report)
# Out:
# 313/313 - 1s - 526ms/epoch - 2ms/step
# Regular NN:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1000
#            1       0.00      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.00      0.00      0.00      1000
#            4       0.00      0.00      0.00      1000
#            5       0.00      0.00      0.00      1000
#            6       0.00      0.00      0.00      1000
#            7       0.00      0.00      0.00      1000
#            8       0.00      0.00      0.00      1000
#            9       0.10      1.00      0.18      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000
# ...

# %%
from sklearn.metrics import classification_report
import numpy as np

reg_pred = reg_model_4.predict(x_test, verbose=2)
reg_pred_classes = np.argmax(reg_pred, axis=1)
reg_true_classes = np.argmax(y_test, axis=1)

cnn_pred = cnn_model_4.predict(x_test, verbose=2)
cnn_pred_classes = np.argmax(cnn_pred, axis=1)
cnn_true_classes = np.argmax(y_test, axis=1)

reg_report = classification_report(reg_true_classes, reg_pred_classes)
cnn_report = classification_report(cnn_true_classes, cnn_pred_classes)

print('Regular NN:\n', reg_report)
print('CNN:\n', cnn_report)
# Out:
# 313/313 - 1s - 701ms/epoch - 2ms/step
# 313/313 - 1s - 676ms/epoch - 2ms/step
# Regular NN:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1000
#            1       0.00      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.00      0.00      0.00      1000
#            4       0.10      1.00      0.18      1000
#            5       0.00      0.00      0.00      1000
#            6       0.00      0.00      0.00      1000
#            7       0.00      0.00      0.00      1000
#            8       0.00      0.00      0.00      1000
#            9       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.01      0.10      0.02     10000
# weighted avg       0.01      0.10      0.02     10000
#
# CNN:
#                precision    recall  f1-score   support
#
# ...
